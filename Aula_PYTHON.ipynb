# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielbini321/PYTHON-/blob/main/Aula_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**AULA 1** 💚 ⏰ ⛹

# %%
print ("I comprtição de programação d Start")
ano = "IX"
print(f"{ano} competição de programação da Start")
# Out:
# IX competição de programação da Start

# %% [markdown]
# ## **AULA 2 ⏰:**

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana  = 2 * livro_ficcao + 5 * livro_infantil
pontos_totais = pontos_rodrigo + pontos_ana
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais do ana são {pontos_ana}")
print(f"Os pontos totais do Rodrigo e de Ana são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais do ana são 46
# Os pontos totais do Rodrigo e de Ana são 70
